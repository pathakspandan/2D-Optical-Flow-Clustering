# %%
import os, re
import glob
import cv2
import numpy as np
import cupy as cp
from cupyx.scipy import ndimage as cpx_ndimage  # Import CuPy's GPU ndimage module
import tifffile as tiff
import scipy as sp
from scipy import ndimage, io as sio
from scipy.ndimage import maximum_filter, label, find_objects
from scipy.stats import chi2
from skimage.feature import peak_local_max
from natsort import natsorted
import trackpy as tp
import pandas as pd
import multiprocessing as mp
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from matplotlib.widgets import Slider
from matplotlib import animation, rc
from tqdm import tqdm
import ipywidgets as widgets
from IPython.display import display, Image

# Set up matplotlib for animations
rc('animation', html='jshtml')

# Suppress specific warnings
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)  # ignore warnings for specific matplotlib commands which will be outdated soon

# %%
data_folder1 = convert_to_code_path(r'E:\Spandan\2D_Neurons_Paper\Glass\div2\control_div2_glass_2019_06_24_cortical_div2_timelapse2_1');
data_folder2 = convert_to_code_path(r'E:\Spandan\2D_Neurons_Paper\Glass\div2\control_div2_glass_2019_06_24_cortical_div2_timelapse1');

control_div2_glass_2019_06_24_cortical_div2_timelapse2_1 = pd.read_csv(data_folder1+'\\tp_trajectories_final.csv')
control_div2_glass_2019_06_24_cortical_div2_timelapse1 = pd.read_csv(data_folder2+'\\tp_trajectories_final.csv')

# Merge along a new axis using MultiIndex
merged_df = pd.concat({'df1': df1, 'df2': df2}, axis=0)

# print(merged_df)

# Save DataFrame as CSV
merged_df.to_csv(data'test.csv', index=True)

# %%
def convert_to_code_path(windows_path):
    """
    Converts a Windows file path with single backslashes to a format with double backslashes for use in Python code.

    Parameters:
    - windows_path: str
        The original Windows file path (e.g., 'C:\\Users\\YourName\\Folder').

    Returns:
    - str
        The modified path with double backslashes, suitable for Python (e.g., 'C:\\\\Users\\\\YourName\\\\Folder').
    """
    # Replace each single backslash with a double backslash
    return windows_path.replace("\\", "\\\\")

def extract_numeric(value):
    """
    Extracts numeric value from a given input. If the input is not numeric,
    it will return None.

    Args:
    - value: The input value to be processed.

    Returns:
    - float or None: The extracted numeric value, or None if the input is not valid.
    """
    # Convert to string and strip any leading/trailing whitespace
    value_str = str(value).strip()

    # Use regex to find numeric values (including decimals)
    match = re.findall(r"[-+]?\d*\.\d+|\d+", value_str)

    if match:
        return float(match[0])  # Return the first found numeric value
    else:
        return None


def get_file_names_and_params_by_div(sheet_path, div_value, sheet_name='ridges'):
    """
    Get all 'file name', 'resolution', and 'frame interval' values from the specified Excel sheet where div equals the given value.

    Args:
    - sheet_path: Path to the Excel sheet containing imaging details.
    - div_value: The 'div' value to filter the Excel sheet.
    - sheet_name: The sheet name in the Excel file (default: 'ridges').

    Returns:
    - params: A list of tuples containing ('file name', 'resolution', 'frame interval') where div equals div_value.
    """
    # Load the Excel sheet
    df_sheet = pd.read_excel(sheet_path, sheet_name=sheet_name)

    # Filter based on the 'div' value
    df_sheet_filtered = df_sheet[df_sheet['div'] == div_value]

    # Get the parameters
    params = []
    for index in df_sheet_filtered.index:
        # Extract file name
        file_name = df_sheet_filtered['file name'][index]

        # Extract frame interval
        interval = df_sheet_filtered['frame interval'][index]
        integer_interval_value = extract_numeric(interval)

        # Extract resolution
        resolution = df_sheet_filtered['resolution'][index]
        integer_resolution_value = extract_numeric(resolution)

        # Append to params
        params.append((file_name, integer_resolution_value, integer_interval_value))

    return params

# %%
def check_level_2_subfolders_by_div_and_params(main_folder, sheet_path, div_value, resolution_range, frame_interval_range):
    """
    Check all level-2 subfolder names under level-1 subfolders that match the specified div value,
    and verify if their corresponding resolution and frame interval match the criteria.
    This function combines data from 'tp_trajectories_final.csv' files and 'fit_' files into one large DataFrame.
    
    Args:
    - main_folder: Path to the main folder containing level-1 subfolders.
    - sheet_path: Path to the Excel sheet containing imaging details.
    - div_value: The 'div' value to filter the Excel sheet.
    - resolution_range: The resolution range to match (as a tuple or list).
    - frame_interval_range: The frame interval range to match (as a tuple or list).
    """
    
    # Get the file names and corresponding parameters that match the div value
    params = get_file_names_and_params_by_div(sheet_path, div_value)
    if not params:
        print(f"No parameters found for div = {div_value}.")
        return

    # Create an empty DataFrame to store combined data
    # combined_df = pd.DataFrame()

    # Loop through each level-1 subfolder
    for subfolder in os.listdir(main_folder):
        subfolder_path = os.path.join(main_folder, subfolder)

        # Check if it's a directory (level-1)
        if os.path.isdir(subfolder_path):
            # Loop through each level-2 subfolder
            for level_2_subfolder in os.listdir(subfolder_path):
                level_2_subfolder_path = os.path.join(subfolder_path, level_2_subfolder)

                if os.path.isdir(level_2_subfolder_path):
                    # Check if this level-2 folder corresponds to any file name
                    for file_name, resolution, frame_interval in params:
                        if file_name in level_2_subfolder:
                            print(f"Analyzing Level-2 Subfolder: {level_2_subfolder}")

                            # Verify if resolution and frame interval meet the criteria
                            if ((resolution_range is None or (resolution is not None and resolution_range[0] <= resolution <= resolution_range[1])) and
                                (frame_interval_range is None or (frame_interval is not None and frame_interval_range[0] <= frame_interval <= frame_interval_range[1]))):
                                
                                print("Criteria Met")

                                # Find 'tp_trajectories_final.csv' and 'fit_' files
                                try:
                                    tp_trajectories_path = convert_to_code_path(os.path.join(level_2_subfolder_path, 'tp_trajectories_final.csv'))
                                    
                                    if os.path.exists(tp_trajectories_path):
                                        # Load tp_trajectories_final.csv
                                        tp_trajectories_df = pd.read_csv(tp_trajectories_path, encoding='ISO-8859-1')
                                        num_unique_tracks = tp_trajectories_df['particle'].nunique()
                                        print(num_unique_tracks)
                                        
                                        # # Add context columns at the start
                                        # tp_trajectories_df.insert(0, 'div_stage', subfolder)  # Add level-1 folder name
                                        # tp_trajectories_df.insert(1, 'file_name', level_2_subfolder)  # Add level-2 folder name
                                        
                                        # # Find and add 'fit_' CSV files as new columns
                                        # for file in os.listdir(level_2_subfolder_path):
                                        #     if file.startswith('fit_') and file.endswith('.csv'):
                                        #         fit_file_path = convert_to_code_path(os.path.join(level_2_subfolder_path, file))
                                        #         fit_df = pd.read_csv(fit_file_path, encoding='ISO-8859-1')
                                        #         # Use the 'fit_' filename as the column name prefix
                                        #         fit_prefix = file.replace('.csv', '')
                                        #         fit_df = fit_df.add_prefix(f"{fit_prefix}_")
                                        #         tp_trajectories_df = pd.concat([tp_trajectories_df, fit_df], axis=1)

                                        # # Append the DataFrame to the combined DataFrame
                                        # combined_df = pd.concat([combined_df, tp_trajectories_df], ignore_index=True)
                                    else:
                                        print(f"No 'tp_trajectories_final.csv' file found in {level_2_subfolder_path}.")
                                
                                except Exception as e:
                                    print(f"Error analyzing data in {level_2_subfolder}: {e}")
                            else:
                                print("Criteria Not Met")

    # # Save the combined DataFrame to a CSV file at the end
    # if not combined_df.empty:
    #     combined_df.to_csv(os.path.join(main_folder, 'combined_trajectories_final.csv'), index=False)
    #     print("Combined .csv file saved as 'combined_trajectories_final.csv'.")
    # else:
    #     print("No valid data to combine.")

# %%
def analyze_all_divs(main_folder, sheet_path, resolution_range, frame_interval_range):
    """
    Analyze all level-1 folders corresponding to different DIV values.

    Parameters:
    - main_folder: Path to the main folder containing level-1 subfolders.
    - sheet_path: Path to the Excel file with additional data.
    - resolution_range: Tuple containing the range of resolutions to filter.
    - frame_interval_range: Tuple containing the range of frame intervals to filter.
    """
    
    # Loop through each level-1 subfolder
    for subfolder in os.listdir(main_folder):
        subfolder_path = os.path.join(main_folder, subfolder)

        # Check if it's a directory (level-1)
        if os.path.isdir(subfolder_path):
            # Use regex to extract the DIV value from the folder name
            match = re.search(r'div(\d+)', subfolder, re.IGNORECASE)
            if match:
                div_value = int(match.group(1))  # Convert extracted string to integer
                print(f"Analyzing {subfolder} with DIV value: {div_value}")

                # Call your analysis function
                check_level_2_subfolders_by_div_and_params(main_folder, sheet_path, div_value, resolution_range, frame_interval_range)

# Example usage

main_folder = r'E:\Spandan\2D_Neurons_Paper\Ridges'
sheet_path = r'E:\Spandan\Kate\NEURON MOVIES\tifNotes.xlsx'
resolution_range = (2.6, 2.9)
frame_interval_range = (1.8, 2.2)

analyze_all_divs(main_folder, sheet_path, resolution_range, frame_interval_range)
# Out:
# Analyzing div2 with DIV value: 2
# Analyzing Level-2 Subfolder: ridges_19_01_21_div2cortex_B1_timelapse2
# Criteria Met
# 17
# Analyzing Level-2 Subfolder: ridges_19_01_21_div2cortex_B1_timelapse3
# Criteria Met
# 17
# Analyzing Level-2 Subfolder: ridges_19_01_21_div2cortex_B1_timelapse5
# Criteria Met
# 18
# Analyzing Level-2 Subfolder: ridges_19_01_21_div2cortex_B1_timelapse6
# Criteria Met
# 20
# Analyzing Level-2 Subfolder: ridges_19_02_11_C2_ridges_timelapse1
# Criteria Met
# 51
# Analyzing Level-2 Subfolder: ridges_19_02_11_C2_ridges_timelapse4a
# Criteria Met
# 28
# Analyzing Level-2 Subfolder: ridges_19_02_11_C2_ridges_timelapse7
# Criteria Met
# 10
# Analyzing Level-2 Subfolder: ridges_2019_02_11_C2_ridges_timelapse1
# Criteria Met
# No 'tp_trajectories_final.csv' file found in E:\Spandan\2D_Neurons_Paper\Ridges\div4\ridges_2019_02_11_C2_ridges_timelapse1.
# Analyzing Level-2 Subfolder: ridges_2019_02_11_C2_ridges_timelapse1
# Criteria Met
# 53
# Analyzing div3 with DIV value: 3
# Analyzing Level-2 Subfolder: ridges_2021_04_16_MAX_well2_timelapse2_PFS
# Criteria Not Met
# Analyzing Level-2 Subfolder: ridges_2021_04_16_MAX_well2_timelapse3_PFS
# Criteria Not Met
# Analyzing Level-2 Subfolder: ridges_2021_04_16_well2_timelapse1_PFS
# Criteria Met
# 7
# Analyzing div4 with DIV value: 4
# Analyzing Level-2 Subfolder: ridges_19_02_11_C2_ridges_timelapse1
# Criteria Met
# 51
# Analyzing Level-2 Subfolder: ridges_2019_02_11_C2_ridges_timelapse1
# Criteria Met
# No 'tp_trajectories_final.csv' file found in E:\Spandan\2D_Neurons_Paper\Ridges\div4\ridges_2019_02_11_C2_ridges_timelapse1.
# Analyzing Level-2 Subfolder: ridges_2019_02_11_C2_ridges_timelapse2
# Criteria Met
# 18
# Analyzing Level-2 Subfolder: ridges_2019_02_11_C2_ridges_timelapse1
# Criteria Met
# 53
# Analyzing div7 with DIV value: 7
# Analyzing Level-2 Subfolder: ridges_2019_01_21_B1_ridges_timelapse1
# Criteria Met
# 66
# Analyzing Level-2 Subfolder: ridges_2019_01_21_B1_ridges_timelapse2
# Criteria Met
# 87
# Analyzing Level-2 Subfolder: ridges_2019_01_21_B2_ridges_timelapse4
# Criteria Met
# 113
# Analyzing Level-2 Subfolder: ridges_2021_04_16_MAX_well1_div7ridges_timelapse1
# Criteria Not Met
# Analyzing Level-2 Subfolder: ridges_2021_04_16_MAX_well1_div7ridges_timelapse2
# Criteria Not Met
# Analyzing Level-2 Subfolder: ridges_2021_04_16_MAX_well1_div7ridges_timelapse4
# Criteria Not Met
# Analyzing div8 with DIV value: 8
# Analyzing Level-2 Subfolder: ridges_19_02_11_C2_ridges_timelapse1
# Criteria Met
# 51
# Analyzing Level-2 Subfolder: ridges_19_02_11_C2_ridges_timelapse4a
# Criteria Met
# 28
# Analyzing Level-2 Subfolder: ridges_2019_02_11_C2_ridges_timelapse1
# Criteria Met
# No 'tp_trajectories_final.csv' file found in E:\Spandan\2D_Neurons_Paper\Ridges\div4\ridges_2019_02_11_C2_ridges_timelapse1.
# Analyzing Level-2 Subfolder: ridges_2019_02_11_C2_ridges_timelapse1
# Criteria Met
# 53
# Analyzing Level-2 Subfolder: ridges_2019_02_11_C2_ridges_timelapse3
# Criteria Met
# 66
# Analyzing Level-2 Subfolder: ridges_2019_02_11_C2_ridges_timelapse4
# Criteria Met
# 84

# %%
yo = pd.read_csv('E:\\Spandan\\2D_Neurons_Paper\\Glass\\div2\\control_div2_glass_2019_01_23_div2cortex_A1_timelapse1\\tp_trajectories_final.csv')

# %%
def convert_to_code_path(windows_path):
    """
    Converts a Windows file path with single backslashes to a format with double backslashes for use in Python code.

    Parameters:
    - windows_path: str
        The original Windows file path (e.g., 'C:\\Users\\YourName\\Folder').

    Returns:
    - str
        The modified path with double backslashes, suitable for Python (e.g., 'C:\\\\Users\\\\YourName\\\\Folder').
    """
    # Replace each single backslash with a double backslash
    return windows_path.replace("\\", "\\\\")

def extract_numeric(value):
    """
    Extracts numeric value from a given input. If the input is not numeric,
    it will return None.

    Args:
    - value: The input value to be processed.

    Returns:
    - float or None: The extracted numeric value, or None if the input is not valid.
    """
    # Convert to string and strip any leading/trailing whitespace
    value_str = str(value).strip()

    # Use regex to find numeric values (including decimals)
    match = re.findall(r"[-+]?\d*\.\d+|\d+", value_str)

    if match:
        return float(match[0])  # Return the first found numeric value
    else:
        return None


def get_file_names_and_params_by_div(sheet_path, div_value, sheet_name='glass'):
    """
    Get all 'file name', 'resolution', and 'frame interval' values from the specified Excel sheet where div equals the given value.

    Args:
    - sheet_path: Path to the Excel sheet containing imaging details.
    - div_value: The 'div' value to filter the Excel sheet.
    - sheet_name: The sheet name in the Excel file (default: 'glass').

    Returns:
    - params: A list of tuples containing ('file name', 'resolution', 'frame interval') where div equals div_value.
    """
    # Load the Excel sheet
    df_sheet = pd.read_excel(sheet_path, sheet_name=sheet_name)

    # Filter based on the 'div' value
    df_sheet_filtered = df_sheet[df_sheet['div'] == div_value]

    # Get the parameters
    params = []
    for index in df_sheet_filtered.index:
        # Extract file name
        file_name = df_sheet_filtered['file name'][index]

        # Extract frame interval
        interval = df_sheet_filtered['frame interval'][index]
        integer_interval_value = extract_numeric(interval)

        # Extract resolution
        resolution = df_sheet_filtered['resolution'][index]
        integer_resolution_value = extract_numeric(resolution)

        # Append to params
        params.append((file_name, integer_resolution_value, integer_interval_value))

    return params

# %%
def check_level_2_subfolders_by_div_and_params(main_folder, sheet_path, div_value, resolution_range, frame_interval_range):
    """
    Check all level-2 subfolder names under level-1 subfolders that match the specified div value,
    and verify if their corresponding resolution and frame interval match the criteria.
    This function combines data from 'tp_trajectories_final.csv' files and 'fit_' files into one large DataFrame.
    
    Args:
    - main_folder: Path to the main folder containing level-1 subfolders.
    - sheet_path: Path to the Excel sheet containing imaging details.
    - div_value: The 'div' value to filter the Excel sheet.
    - resolution_range: The resolution range to match (as a tuple or list).
    - frame_interval_range: The frame interval range to match (as a tuple or list).
    """
    
    # Get the file names and corresponding parameters that match the div value
    params = get_file_names_and_params_by_div(sheet_path, div_value)
    if not params:
        print(f"No parameters found for div = {div_value}.")
        return

    # Create an empty DataFrame to store combined data
    # combined_df = pd.DataFrame()

    # Loop through each level-1 subfolder
    for subfolder in os.listdir(main_folder):
        subfolder_path = os.path.join(main_folder, subfolder)

        # Check if it's a directory (level-1)
        if os.path.isdir(subfolder_path):
            # Loop through each level-2 subfolder
            for level_2_subfolder in os.listdir(subfolder_path):
                level_2_subfolder_path = os.path.join(subfolder_path, level_2_subfolder)

                if os.path.isdir(level_2_subfolder_path):
                    # Check if this level-2 folder corresponds to any file name
                    for file_name, resolution, frame_interval in params:
                        if file_name in level_2_subfolder:
                            print(f"Analyzing Level-2 Subfolder: {level_2_subfolder}")

                            # Verify if resolution and frame interval meet the criteria
                            if ((resolution_range is None or (resolution is not None and resolution_range[0] <= resolution <= resolution_range[1])) and
                                (frame_interval_range is None or (frame_interval is not None and frame_interval_range[0] <= frame_interval <= frame_interval_range[1]))):
                                
                                print("Criteria Met")

                                # Find 'tp_trajectories_final.csv' and 'fit_' files
                                try:
                                    tp_trajectories_path = convert_to_code_path(os.path.join(level_2_subfolder_path, 'track_metrics.csv'))
                                    
                                    if os.path.exists(tp_trajectories_path):
                                        # Load tp_trajectories_final.csv
                                        tp_trajectories_df = pd.read_csv(tp_trajectories_path, encoding='ISO-8859-1')
                                        num_unique_tracks = tp_trajectories_df['particle'].nunique()
                                        print(num_unique_tracks)
                                        
                                        # # Add context columns at the start
                                        # tp_trajectories_df.insert(0, 'div_stage', subfolder)  # Add level-1 folder name
                                        # tp_trajectories_df.insert(1, 'file_name', level_2_subfolder)  # Add level-2 folder name
                                        
                                        # # Find and add 'fit_' CSV files as new columns
                                        # for file in os.listdir(level_2_subfolder_path):
                                        #     if file.startswith('fit_') and file.endswith('.csv'):
                                        #         fit_file_path = convert_to_code_path(os.path.join(level_2_subfolder_path, file))
                                        #         fit_df = pd.read_csv(fit_file_path, encoding='ISO-8859-1')
                                        #         # Use the 'fit_' filename as the column name prefix
                                        #         fit_prefix = file.replace('.csv', '')
                                        #         fit_df = fit_df.add_prefix(f"{fit_prefix}_")
                                        #         tp_trajectories_df = pd.concat([tp_trajectories_df, fit_df], axis=1)

                                        # # Append the DataFrame to the combined DataFrame
                                        # combined_df = pd.concat([combined_df, tp_trajectories_df], ignore_index=True)
                                    else:
                                        print(f"No 'track_metrics.csv' file found in {level_2_subfolder_path}.")
                                
                                except Exception as e:
                                    print(f"Error analyzing data in {level_2_subfolder}: {e}")
                            else:
                                print("Criteria Not Met")

    # # Save the combined DataFrame to a CSV file at the end
    # if not combined_df.empty:
    #     combined_df.to_csv(os.path.join(main_folder, 'combined_trajectories_final.csv'), index=False)
    #     print("Combined .csv file saved as 'combined_trajectories_final.csv'.")
    # else:
    #     print("No valid data to combine.")

# %%
def analyze_all_divs(main_folder, sheet_path, resolution_range, frame_interval_range):
    """
    Analyze all level-1 folders corresponding to different DIV values.

    Parameters:
    - main_folder: Path to the main folder containing level-1 subfolders.
    - sheet_path: Path to the Excel file with additional data.
    - resolution_range: Tuple containing the range of resolutions to filter.
    - frame_interval_range: Tuple containing the range of frame intervals to filter.
    """
    
    # Loop through each level-1 subfolder
    for subfolder in os.listdir(main_folder):
        subfolder_path = os.path.join(main_folder, subfolder)

        # Check if it's a directory (level-1)
        if os.path.isdir(subfolder_path):
            # Use regex to extract the DIV value from the folder name
            match = re.search(r'div(\d+)', subfolder, re.IGNORECASE)
            if match:
                div_value = int(match.group(1))  # Convert extracted string to integer
                print(f"Analyzing {subfolder} with DIV value: {div_value}")

                # Call your analysis function
                check_level_2_subfolders_by_div_and_params(main_folder, sheet_path, div_value, resolution_range, frame_interval_range)

# Example usage

main_folder = r'E:\Spandan\2D_Neurons_Paper\Glass'
sheet_path = r'E:\Spandan\Kate\NEURON MOVIES\tifNotes.xlsx'
resolution_range = (2.7, 2.8)
frame_interval_range = (1.9, 2.1)

analyze_all_divs(main_folder, sheet_path, resolution_range, frame_interval_range)
# Out:
# Analyzing div10 with DIV value: 10
# Analyzing Level-2 Subfolder: control_div10_glass_2019_04_22_NewPdl_GFP RFP_5 5_488_timelapse1
# Criteria Met
# 68
# Analyzing Level-2 Subfolder: control_div10_glass_2021_04_12_MAX_6well1_div10_timelapse3_100x
# Criteria Not Met
# Analyzing Level-2 Subfolder: control_div10_glass_2021_12_06_dish2_control_neuron1_media
# Criteria Met
# 109
# Analyzing Level-2 Subfolder: control_div10_glass_2021_12_06_dish2_control_neuron2_media
# Criteria Met
# 121
# Analyzing Level-2 Subfolder: control_div10_glass_2021_12_06_dish2_control_neuron3_media
# Criteria Met
# 65
# Analyzing Level-2 Subfolder: control_div10_glass_2021_12_06_dish2_control_neuron4_media
# Criteria Met
# 91
# Analyzing Level-2 Subfolder: control_div10_glass_2021_12_06_dish2_control_neuron5_media
# Criteria Met
# 82
# Analyzing div11 with DIV value: 11
# Analyzing Level-2 Subfolder: control_2019_02_11_CL+DIV3_Cort_timelapse2
# Criteria Not Met
# Analyzing Level-2 Subfolder: control_2019_02_11_CL+DIV7_Cort_timelapse5
# Criteria Met
# 210
# Analyzing div12 with DIV value: 12
# Analyzing Level-2 Subfolder: control_2018_08_24_MAX_Cx_40x_B1+CLonDIV3_timelapse1
# Criteria Met
# 96
# Analyzing div14 with DIV value: 14
# Analyzing Level-2 Subfolder: control_2019_02_11_Cort_DIV3_top_timelapse1
# Criteria Met
# 470
# Analyzing Level-2 Subfolder: control_2019_02_11_plate1_timelapse1
# Criteria Met
# 54
# Analyzing Level-2 Subfolder: control_2019_09_13_MAX_control_timelapse1
# Criteria Not Met
# Analyzing Level-2 Subfolder: control_2019_02_11_Cort_DIV17_plate1_timelapse1
# Criteria Met
# No 'track_metrics.csv' file found in E:\Spandan\2D_Neurons_Paper\Glass\div17\control_2019_02_11_Cort_DIV17_plate1_timelapse1.
# Analyzing div16 with DIV value: 16
# Analyzing Level-2 Subfolder: control_2019_03_24_Cort_CL+DIV10_timelapse1
# Criteria Met
# 72
# Analyzing Level-2 Subfolder: control_2019_03_24_Cort_CL+DIV6_timelapse2
# Criteria Met
# 17
# Analyzing Level-2 Subfolder: control_2019_03_24_Cort_CL+DIV6_timelapse2_2
# Criteria Met
# 26
# Analyzing Level-2 Subfolder: control_2019_03_24_Cort_CL+DIV6_timelapse2_2
# Criteria Met
# 26
# Analyzing Level-2 Subfolder: control_2019_03_24_Cort_CL+enhancerDIV10_timelapse1
# Criteria Met
# 86
# Analyzing Level-2 Subfolder: control_2019_03_24_Cort_CL+enhancerDIV10_timelapse2_2
# Criteria Met
# 208
# Analyzing Level-2 Subfolder: control_2019_03_24_Cort_CL+enhancerDIV6_timelapse1
# Criteria Met
# 55
# Analyzing Level-2 Subfolder: control_2019_03_24_Cort_CL+enhancerDIV6_timelapse2
# Criteria Met
# 88
# Analyzing div17 with DIV value: 17
# Analyzing Level-2 Subfolder: control_2019_02_11_Cort_DIV17_plate1_timelapse1
# Criteria Met
# No 'track_metrics.csv' file found in E:\Spandan\2D_Neurons_Paper\Glass\div17\control_2019_02_11_Cort_DIV17_plate1_timelapse1.
# Analyzing Level-2 Subfolder: control_2019_02_11_Cort_DIV17_plate1_timelapse2
# Criteria Met
# 259
# Analyzing Level-2 Subfolder: control_2019_02_11_Cort_DIV17_plate1_timelapse3
# Criteria Met
# 37
# Analyzing Level-2 Subfolder: control_2019_02_11_Cort_DIV17_plate1_timelapse4
# Criteria Met
# 174
# Analyzing Level-2 Subfolder: control_2019_02_11_Cort_DIV17_plate2_timelapse1
# Criteria Met
# 256
# Analyzing div2 with DIV value: 2
# Analyzing Level-2 Subfolder: control_div2_glass_2018_10_01_MAX_60X_B1_timelapse1
# Criteria Not Met
# Analyzing Level-2 Subfolder: control_div2_glass_2019_01_23_div2cortex_A1_timelapse1
# Criteria Met
# 25
# Analyzing Level-2 Subfolder: control_div2_glass_2019_01_23_div2cortex_A1_timelapse2
# Criteria Met
# 34
# Analyzing Level-2 Subfolder: control_div2_glass_2019_01_23_div2cortex_A1_timelapse3
# Criteria Met
# 16
# Analyzing Level-2 Subfolder: control_div2_glass_2019_01_23_div2cortex_C1_timelapse1_2secPerTP_5min
# Criteria Met
# 86
# Analyzing Level-2 Subfolder: control_div2_glass_2019_01_23_div2cortex_C1_timelapse2_2secPerTP_5min
# Criteria Met
# 70
# Analyzing Level-2 Subfolder: control_div2_glass_2019_01_23_div2cortex_C1_timelapse3_2secPerTP_10min
# Criteria Met
# 62
# Analyzing Level-2 Subfolder: control_div2_glass_2019_06_24_cortical_div2_timelapse1
# Criteria Met
# 57
# Analyzing Level-2 Subfolder: control_div2_glass_2019_06_24_cortical_div2_timelapse2_1
# Criteria Met
# 242
# Analyzing div21 with DIV value: 21
# Analyzing Level-2 Subfolder: control_2019_02_11_Coth_+CLDIV14_timelapse
# Criteria Met
# 77
# Analyzing Level-2 Subfolder: control_2019_04_22_Cort_DIV21_+CLDIV17_NewPDL_timelapse2a
# Criteria Met
# 41
# Analyzing Level-2 Subfolder: control_2019_04_22_Cort_DIV21_+CLDIV17_NewPDL_timelapse2b
# Criteria Met
# 53
# Analyzing div23 with DIV value: 23
# Analyzing Level-2 Subfolder: control_div23_glass_2018_10_01_MAX_B4_timelapse1
# Criteria Not Met
# Analyzing Level-2 Subfolder: control_div23_glass_2018_10_01_MAX_B4_timelapse2
# Criteria Not Met
# Analyzing Level-2 Subfolder: control_div23_glass_2018_10_01_MAX_C4_timelapse1
# Criteria Not Met
# Analyzing Level-2 Subfolder: control_div23_glass_2018_10_01_MAX_D4_timelapse1
# Criteria Not Met
# Analyzing Level-2 Subfolder: control_div23_glass_2018_10_01_MAX_D4_timelapse2
# Criteria Not Met
# Analyzing Level-2 Subfolder: control_div23_glass_2018_10_01_MAX_D4_timelapse3
# Criteria Not Met
# Analyzing Level-2 Subfolder: control_div23_glass_2019_04_22_CortDIV23_+ClDIV17+en_timelapse1
# Criteria Met
# 122
# Analyzing Level-2 Subfolder: control_div23_glass_2019_04_22_CortDIV23_+ClDIV17+en_timelapse1b
# Criteria Met
# 71
# Analyzing Level-2 Subfolder: control_div23_glass_2019_04_22_CortDIV23_+ClDIV17+en_timelapse1b
# Criteria Met
# 71
# Analyzing div3 with DIV value: 3
# Analyzing Level-2 Subfolder: control_2018_11_02_MAX_cortical_glass+PDL+Lam_timelapse1
# Criteria Not Met
# Analyzing Level-2 Subfolder: control_2018_11_02_MAX_cortical_glass+PDL+Lam_timelapse2
# Criteria Not Met
# Analyzing Level-2 Subfolder: control_2018_11_02_MAX_cortical_glass+PDL_timelapse1
# Criteria Not Met
# Analyzing Level-2 Subfolder: control_2019_01_21_div3cortex_timelapse1
# Criteria Met
# 205
# Analyzing Level-2 Subfolder: control_2019_01_21_div3cortex_timelapse2
# Criteria Met
# 96
# Analyzing Level-2 Subfolder: control_2019_01_21_div3cortex_timelapse3
# Criteria Met
# 42
# Analyzing Level-2 Subfolder: control_2019_01_21_div3cortex_timelapse4
# Criteria Met
# 63
# Analyzing Level-2 Subfolder: control_2019_01_21_div3cortex_TranOnDIV2_timelapse4
# Criteria Met
# No 'track_metrics.csv' file found in E:\Spandan\2D_Neurons_Paper\Glass\div3\control_2019_01_21_div3cortex_TranOnDIV2_timelapse4.
# Analyzing Level-2 Subfolder: control_2019_03_24_div3_corticalNeurons_timelapse1_preEfield_5min
# Criteria Met
# 58
# Analyzing Level-2 Subfolder: control_2020_02_21_MAX_ratneurons_Div3_control_timelapse_1
# Criteria Not Met
# Analyzing Level-2 Subfolder: control_2020_02_21_MAX_ratneurons_Div3_control_timelapse_2
# Criteria Not Met
# Analyzing Level-2 Subfolder: control_2020_02_21_MAX_ratneurons_Div3_control_timelapse_3
# Criteria Not Met
# Analyzing div4 with DIV value: 4
# Analyzing Level-2 Subfolder: control_2019_09_13_MAX_control_div4cortex_timelapse1
# Criteria Not Met
# Analyzing Level-2 Subfolder: control_2019_09_13_MAX_control_div4cortex_timelapse2
# Criteria Not Met
# Analyzing div5 with DIV value: 5
# Analyzing Level-2 Subfolder: control_2018_07_20_MAX_A1_40x_timelapse2 (2 sec per T)
# Criteria Met
# 74
# Analyzing Level-2 Subfolder: control_2018_07_20_MAX_A3_40x_timelapse2 (2 sec per T)
# Criteria Met
# 49
# Analyzing Level-2 Subfolder: control_2018_07_20_MAX_A3_40x_timelapse3 (5 sec per T)
# Criteria Not Met
# Analyzing Level-2 Subfolder: control_2018_07_20_MAX_A4_40x_timelapse1 (1 sec per T)
# Criteria Not Met
# Analyzing Level-2 Subfolder: control_2018_08_24_MAX_40x_Cx_CellLight on DIV3 for48h_488_timelapse1
# Criteria Met
# 91
# Analyzing Level-2 Subfolder: control_2018_08_24_MAX_40x_Cx_CellLight on DIV3 for48h_488_timelapse2
# Criteria Met
# 48
# Analyzing Level-2 Subfolder: control_2018_08_24_MAX_40x_Cx_CellLight on DIV3 for48h_488_timelapse3
# Criteria Met
# 123
# Analyzing div7 with DIV value: 7
# Analyzing Level-2 Subfolder: control_2018_08_24_MAX_Cx_A1_24h on DIV3_488_timelapse2
# Criteria Met
# 87
# Analyzing Level-2 Subfolder: control_2018_08_24_MAX_Cx_B1_48h on DIV3_488_timelapse3
# Criteria Met
# 88
# Analyzing Level-2 Subfolder: control_2018_08_24_MAX_Cx_C1_24h on DIV6_488_timelapse6
# Criteria Met
# 130
# Analyzing Level-2 Subfolder: control_2018_10_01_MAX_40x_CX6well_+PDL+LAMglass_Movie2
# Criteria Met
# 194
# Analyzing Level-2 Subfolder: control_2018_10_01_MAX_40x_CX6Well_PDL+LAMGlass_Movie1
# Criteria Not Met
# Analyzing Level-2 Subfolder: control_2019_01_21_C1_glass+PDL_timelapse1
# Criteria Met
# 96
# Analyzing Level-2 Subfolder: control_2019_01_21_C2_glass+PDL_timelapse1
# Criteria Met
# 73
# Analyzing Level-2 Subfolder: control_2019_01_21_C2_glass+PDL_timelapse2
# Criteria Met
# 96
# Analyzing Level-2 Subfolder: control_2019_04_22_GFPonly_DIV7_timelapse
# Criteria Met
# 37
# Analyzing Level-2 Subfolder: control_2019_04_22_GFP_RFP 2.5_2.5 DIV7 488_561 timelapse3_C1
# Criteria Met
# 109
# Analyzing Level-2 Subfolder: control_2019_04_22_GFP_RFP 5_5 DIV7 488_561 timelapse1_C1
# Criteria Met
# 107
# Analyzing Level-2 Subfolder: control_2019_06_24_cortical_div7_timelapse_2
# Criteria Met
# 391
# Analyzing Level-2 Subfolder: control_2019_06_24_cortical_div7_timelapse_3
# Criteria Not Met
# Analyzing Level-2 Subfolder: control_2020_03_06_MAX_ timelapse4_cell2_100x
# Criteria Not Met
# Analyzing Level-2 Subfolder: control_2020_03_06_MAX_timelapse1_cell1_40x
# Criteria Not Met
# Analyzing Level-2 Subfolder: control_2020_03_06_MAX_timelapse2_cell1_100x
# Criteria Not Met
# Analyzing Level-2 Subfolder: control_2020_03_06_MAX_timelapse3_cell2_40x
# Criteria Not Met
# Analyzing Level-2 Subfolder: control_2021_12_06_div7neurons_dish1_15mm_40x_neuron1_media
# Criteria Met
# 59
# Analyzing Level-2 Subfolder: control_2021_12_06_div7neurons_dish1_15mm_40x_neuron2_media
# Criteria Met
# 72
# Analyzing Level-2 Subfolder: control_2021_12_06_div7neurons_dish1_15mm_40x_neuron3_media
# Criteria Met
# No 'track_metrics.csv' file found in E:\Spandan\2D_Neurons_Paper\Glass\div7\control_2021_12_06_div7neurons_dish1_15mm_40x_neuron3_media.
# Analyzing div8 with DIV value: 8
# Analyzing Level-2 Subfolder: control_2019_03_24_div8cortex_timelapse1_noStim
# Criteria Not Met
# Analyzing Level-2 Subfolder: control_2021_04_12_MAX_6wellPlate_timelapse1_100x
# Criteria Not Met
# Analyzing Level-2 Subfolder: control_2021_04_12_MAX_6wellPlate_timelapse2_100x
# Criteria Not Met
# Analyzing Level-2 Subfolder: control_2021_04_12_MAX_6wellPlate_timelapse3_100x
# Criteria Not Met
